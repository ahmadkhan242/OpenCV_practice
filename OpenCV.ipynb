# %%
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline
import cv2

# %%
img = cv2.imread('pic.jpg')

# %%
plt.imshow(img)

# %%
newImage = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(newImage)

# %%
grayImage = cv2.imread('pic.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(grayImage)

# %%
plt.imshow(grayImage,cmap='gray')
